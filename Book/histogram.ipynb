# %%
from matplotlib import pyplot as plt
from collections import Counter
grades = [83,95,91,87,70,0,85,82,100,67,73,77,0]
decile = lambda grade: grade // 10*10
histogram = Counter(decile(grade) for grade in grades) 
plt.bar([x - 0.1 for x in histogram.keys()],histogram.values(),8)
plt.axis([-5,105,0,5])
plt.xticks([10 * i for i in range(11)])
# Out:
# ([<matplotlib.axis.XTick at 0x7ff941175040>,
#   <matplotlib.axis.XTick at 0x7ff94117bfd0>,
#   <matplotlib.axis.XTick at 0x7ff9412e2730>,
#   <matplotlib.axis.XTick at 0x7ff941124a60>,
#   <matplotlib.axis.XTick at 0x7ff941124f70>,
#   <matplotlib.axis.XTick at 0x7ff941130160>,
#   <matplotlib.axis.XTick at 0x7ff941130670>,
#   <matplotlib.axis.XTick at 0x7ff941130b80>,
#   <matplotlib.axis.XTick at 0x7ff9411370d0>,
#   <matplotlib.axis.XTick at 0x7ff9411375e0>,
#   <matplotlib.axis.XTick at 0x7ff941137af0>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
